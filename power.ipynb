# %% [markdown]
# data framing

# %%
import pandas as pd

df = pd.read_csv(r"C:\Users\boopa\Desktop\DS\PowerPulse Household Energy Usage Forecast\household_power_consumption.txt", sep=";", header=0)

df
# Out:
# C:\Users\boopa\AppData\Local\Temp\ipykernel_11720\3584277872.py:3: DtypeWarning: Columns (0: Global_active_power, 1: Global_reactive_power, 2: Voltage, 3: Global_intensity, 4: Sub_metering_1, 5: Sub_metering_2) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(r"C:\Users\boopa\Desktop\DS\PowerPulse Household Energy Usage Forecast\household_power_consumption.txt", sep=";", header=0)
#                Date      Time Global_active_power Global_reactive_power  \
# 0        16/12/2006  17:24:00               4.216                 0.418
# 1        16/12/2006  17:25:00               5.360                 0.436
# 2        16/12/2006  17:26:00               5.374                 0.498
# 3        16/12/2006  17:27:00               5.388                 0.502
# 4        16/12/2006  17:28:00               3.666                 0.528
# ...             ...       ...                 ...                   ...
# 2075254  26/11/2010  20:58:00               0.946                   0.0
# 2075255  26/11/2010  20:59:00               0.944                   0.0
# 2075256  26/11/2010  21:00:00               0.938                   0.0
# 2075257  26/11/2010  21:01:00               0.934                   0.0
# 2075258  26/11/2010  21:02:00               0.932                   0.0
#
#          Voltage Global_intensity Sub_metering_1 Sub_metering_2  \
# 0        234.840           18.400          0.000          1.000
# 1        233.630           23.000          0.000          1.000
# 2        233.290           23.000          0.000          2.000
# 3        233.740           23.000          0.000          1.000
# 4        235.680           15.800          0.000          1.000
# ...          ...              ...            ...            ...
# 2075254   240.43              4.0            0.0            0.0
# 2075255    240.0              4.0            0.0            0.0
# 2075256   239.82              3.8            0.0            0.0
# 2075257    239.7              3.8            0.0            0.0
# 2075258   239.55              3.8            0.0            0.0
#
#          Sub_metering_3
# 0                  17.0
# 1                  16.0
# 2                  17.0
# 3                  17.0
# 4                  17.0
# ...                 ...
# 2075254             0.0
# 2075255             0.0
# 2075256             0.0
# 2075257             0.0
# 2075258             0.0
#
# [2075259 rows x 9 columns]

# %% [markdown]
# to date time

# %%
df["Datetime"]=pd.to_datetime(df["Date"]+" "+df["Time"], format="%d/%m/%Y %H:%M:%S")
df
# Out:
#                Date      Time Global_active_power Global_reactive_power  \
# 0        16/12/2006  17:24:00               4.216                 0.418
# 1        16/12/2006  17:25:00               5.360                 0.436
# 2        16/12/2006  17:26:00               5.374                 0.498
# 3        16/12/2006  17:27:00               5.388                 0.502
# 4        16/12/2006  17:28:00               3.666                 0.528
# ...             ...       ...                 ...                   ...
# 2075254  26/11/2010  20:58:00               0.946                   0.0
# 2075255  26/11/2010  20:59:00               0.944                   0.0
# 2075256  26/11/2010  21:00:00               0.938                   0.0
# 2075257  26/11/2010  21:01:00               0.934                   0.0
# 2075258  26/11/2010  21:02:00               0.932                   0.0
#
#          Voltage Global_intensity Sub_metering_1 Sub_metering_2  \
# 0        234.840           18.400          0.000          1.000
# 1        233.630           23.000          0.000          1.000
# 2        233.290           23.000          0.000          2.000
# 3        233.740           23.000          0.000          1.000
# 4        235.680           15.800          0.000          1.000
# ...          ...              ...            ...            ...
# 2075254   240.43              4.0            0.0            0.0
# 2075255    240.0              4.0            0.0            0.0
# 2075256   239.82              3.8            0.0            0.0
# 2075257    239.7              3.8            0.0            0.0
# 2075258   239.55              3.8            0.0            0.0
#
#          Sub_metering_3            Datetime
# 0                  17.0 2006-12-16 17:24:00
# 1                  16.0 2006-12-16 17:25:00
# 2                  17.0 2006-12-16 17:26:00
# 3                  17.0 2006-12-16 17:27:00
# 4                  17.0 2006-12-16 17:28:00
# ...                 ...                 ...
# 2075254             0.0 2010-11-26 20:58:00
# 2075255             0.0 2010-11-26 20:59:00
# 2075256             0.0 2010-11-26 21:00:00
# 2075257             0.0 2010-11-26 21:01:00
# 2075258             0.0 2010-11-26 21:02:00
#
# [2075259 rows x 10 columns]

# %% [markdown]
# removing old date and time

# %%
df.drop(columns=["Date", "Time"], inplace=True)
df
# Out:
#         Global_active_power Global_reactive_power  Voltage Global_intensity  \
# 0                     4.216                 0.418  234.840           18.400
# 1                     5.360                 0.436  233.630           23.000
# 2                     5.374                 0.498  233.290           23.000
# 3                     5.388                 0.502  233.740           23.000
# 4                     3.666                 0.528  235.680           15.800
# ...                     ...                   ...      ...              ...
# 2075254               0.946                   0.0   240.43              4.0
# 2075255               0.944                   0.0    240.0              4.0
# 2075256               0.938                   0.0   239.82              3.8
# 2075257               0.934                   0.0    239.7              3.8
# 2075258               0.932                   0.0   239.55              3.8
#
#         Sub_metering_1 Sub_metering_2  Sub_metering_3            Datetime
# 0                0.000          1.000            17.0 2006-12-16 17:24:00
# 1                0.000          1.000            16.0 2006-12-16 17:25:00
# 2                0.000          2.000            17.0 2006-12-16 17:26:00
# 3                0.000          1.000            17.0 2006-12-16 17:27:00
# 4                0.000          1.000            17.0 2006-12-16 17:28:00
# ...                ...            ...             ...                 ...
# 2075254            0.0            0.0             0.0 2010-11-26 20:58:00
# 2075255            0.0            0.0             0.0 2010-11-26 20:59:00
# 2075256            0.0            0.0             0.0 2010-11-26 21:00:00
# 2075257            0.0            0.0             0.0 2010-11-26 21:01:00
# 2075258            0.0            0.0             0.0 2010-11-26 21:02:00
#
# [2075259 rows x 8 columns]

# %%
print(df)
# Out:
#         Global_active_power Global_reactive_power  Voltage Global_intensity  \
# 0                     4.216                 0.418  234.840           18.400
# 1                     5.360                 0.436  233.630           23.000
# 2                     5.374                 0.498  233.290           23.000
# 3                     5.388                 0.502  233.740           23.000
# 4                     3.666                 0.528  235.680           15.800
# ...                     ...                   ...      ...              ...
# 2075254               0.946                   0.0   240.43              4.0
# 2075255               0.944                   0.0    240.0              4.0
# 2075256               0.938                   0.0   239.82              3.8
# 2075257               0.934                   0.0    239.7              3.8
# 2075258               0.932                   0.0   239.55              3.8
#
#         Sub_metering_1 Sub_metering_2  Sub_metering_3            Datetime
# 0                0.000          1.000            17.0 2006-12-16 17:24:00
# 1                0.000          1.000            16.0 2006-12-16 17:25:00
# 2                0.000          2.000            17.0 2006-12-16 17:26:00
# 3                0.000          1.000            17.0 2006-12-16 17:27:00
# 4                0.000          1.000            17.0 2006-12-16 17:28:00
# ...                ...            ...             ...                 ...
# 2075254            0.0            0.0             0.0 2010-11-26 20:58:00
# 2075255            0.0            0.0             0.0 2010-11-26 20:59:00
# 2075256            0.0            0.0             0.0 2010-11-26 21:00:00
# 2075257            0.0            0.0             0.0 2010-11-26 21:01:00
# 2075258            0.0            0.0             0.0 2010-11-26 21:02:00
#
# [2075259 rows x 8 columns]

# %% [markdown]
# EDA

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2075259 entries, 0 to 2075258
# Data columns (total 8 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   Global_active_power    object
#  1   Global_reactive_power  object
#  2   Voltage                object
#  3   Global_intensity       object
#  4   Sub_metering_1         object
#  5   Sub_metering_2         object
#  6   Sub_metering_3         float64
#  7   Datetime               datetime64[us]
# dtypes: datetime64[us](1), float64(1), object(6)
# memory usage: 126.7+ MB

# %%
df.isna().sum()
# Out:
# Global_active_power          0
# Global_reactive_power        0
# Voltage                      0
# Global_intensity             0
# Sub_metering_1               0
# Sub_metering_2               0
# Sub_metering_3           25979
# Datetime                     0
# dtype: int64

# %%
df.describe()
# Out:
#        Sub_metering_3             Datetime
# count    2.049280e+06              2075259
# mean     6.458447e+00  2008-12-06 07:13:00
# min      0.000000e+00  2006-12-16 17:24:00
# 25%      0.000000e+00  2007-12-12 00:18:30
# 50%      1.000000e+00  2008-12-06 07:13:00
# 75%      1.700000e+01  2009-12-01 14:07:30
# max      3.100000e+01  2010-11-26 21:02:00
# std      8.437154e+00                  NaN

# %%
df.Datetime.min(),df.Datetime.max()
# Out:
# (Timestamp('2006-12-16 17:24:00'), Timestamp('2010-11-26 21:02:00'))

# %%
df["hour"]=df["Datetime"].dt.hour
df["day"]=df["Datetime"].dt.day
df["month"]=df["Datetime"].dt.month
df["weekday"]=df["Datetime"].dt.day_name()
df
# Out:
#         Global_active_power Global_reactive_power  Voltage Global_intensity  \
# 0                     4.216                 0.418  234.840           18.400
# 1                     5.360                 0.436  233.630           23.000
# 2                     5.374                 0.498  233.290           23.000
# 3                     5.388                 0.502  233.740           23.000
# 4                     3.666                 0.528  235.680           15.800
# ...                     ...                   ...      ...              ...
# 2075254               0.946                   0.0   240.43              4.0
# 2075255               0.944                   0.0    240.0              4.0
# 2075256               0.938                   0.0   239.82              3.8
# 2075257               0.934                   0.0    239.7              3.8
# 2075258               0.932                   0.0   239.55              3.8
#
#         Sub_metering_1 Sub_metering_2  Sub_metering_3            Datetime  \
# 0                0.000          1.000            17.0 2006-12-16 17:24:00
# 1                0.000          1.000            16.0 2006-12-16 17:25:00
# 2                0.000          2.000            17.0 2006-12-16 17:26:00
# 3                0.000          1.000            17.0 2006-12-16 17:27:00
# 4                0.000          1.000            17.0 2006-12-16 17:28:00
# ...                ...            ...             ...                 ...
# 2075254            0.0            0.0             0.0 2010-11-26 20:58:00
# 2075255            0.0            0.0             0.0 2010-11-26 20:59:00
# 2075256            0.0            0.0             0.0 2010-11-26 21:00:00
# 2075257            0.0            0.0             0.0 2010-11-26 21:01:00
# 2075258            0.0            0.0             0.0 2010-11-26 21:02:00
#
#          hour  day  month   weekday
# 0          17   16     12  Saturday
# 1          17   16     12  Saturday
# 2          17   16     12  Saturday
# 3          17   16     12  Saturday
# 4          17   16     12  Saturday
# ...       ...  ...    ...       ...
# 2075254    20   26     11    Friday
# 2075255    20   26     11    Friday
# 2075256    21   26     11    Friday
# 2075257    21   26     11    Friday
# 2075258    21   26     11    Friday
#
# [2075259 rows x 12 columns]

# %%
import matplotlib.pyplot as plt
df["Global_active_power"].hist()
plt.title("distribution of  global active power")
plt.xlable("KW")
plt.ylable("frequency")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 2
#       1 import matplotlib.pyplot as plt
# ----> 2 df["Global_active_power"].hist()
#       3 plt.title("distribution of  global active power")
#       4 plt.xlable("KW")
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\pandas\plotting\_core.py:132, in hist_series(self, by, ax, grid, xlabelsize, xrot, ylabelsize, yrot, figsize, bins, backend, legend, **kwargs)
#      65 """
#      66 Draw histogram of the input series using matplotlib.
#      67
#    (...)    129     >>> hist = ser.groupby(level=0).hist()
#     130 """
#     131 plot_backend = _get_plot_backend(backend)
# --> 132 return plot_backend.hist_series(
#     133     self,
#     134     by=by,
#     135     ax=ax,
#     136     grid=grid,
#     137     xlabelsize=xlabelsize,
#     138     xrot=xrot,
#     139     ylabelsize=ylabelsize,
#     140     yrot=yrot,
#     141     figsize=figsize,
#     142     bins=bins,
#     143     legend=legend,
#     144     **kwargs,
#     145 )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\pandas\plotting\_matplotlib\hist.py:452, in hist_series(self, by, ax, grid, xlabelsize, xrot, ylabelsize, yrot, figsize, bins, legend, **kwds)
#     450 if legend:
#     451     kwds["label"] = self.name
# --> 452 ax.hist(values, bins=bins, **kwds)
#     453 if legend:
#     454     ax.legend()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\matplotlib\_api\deprecation.py:453, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     447 if len(args) > name_idx:
#     448     warn_deprecated(
#     449         since, message="Passing the %(name)s %(obj_type)s "
#     450         "positionally is deprecated since Matplotlib %(since)s; the "
#     451         "parameter will become keyword-only in %(removal)s.",
#     452         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 453 return func(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\matplotlib\__init__.py:1524, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1521 @functools.wraps(func)
#    1522 def inner(ax, *args, data=None, **kwargs):
#    1523     if data is None:
# -> 1524         return func(
#    1525             ax,
#    1526             *map(cbook.sanitize_sequence, args),
#    1527             **{k: cbook.sanitize_sequence(v) for k, v in kwargs.items()})
#    1529     bound = new_sig.bind(ax, *args, **kwargs)
#    1530     auto_label = (bound.arguments.get(label_namer)
#    1531                   or bound.kwargs.get(label_namer))
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\matplotlib\axes\_axes.py:7053, in Axes.hist(self, x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, **kwargs)
#    7051 if orientation == "vertical":
#    7052     convert_units = self.convert_xunits
# -> 7053     x = [*self._process_unit_info([("x", x[0])], kwargs),
#    7054          *map(convert_units, x[1:])]
#    7055 else:  # horizontal
#    7056     convert_units = self.convert_yunits
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\matplotlib\axes\_base.py:2663, in _AxesBase._process_unit_info(self, datasets, kwargs, convert)
#    2661     # Update from data if axis is already set but no unit is set yet.
#    2662     if axis is not None and data is not None and not axis.have_units():
# -> 2663         axis.update_units(data)
#    2664 for axis_name, axis in axis_map.items():
#    2665     # Return if no axis is set.
#    2666     if axis is None:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\matplotlib\axis.py:1754, in Axis.update_units(self, data)
#    1752 neednew = self._converter != converter
#    1753 self._set_converter(converter)
# -> 1754 default = self._converter.default_units(data, self)
#    1755 if default is not None and self.units is None:
#    1756     self.set_units(default)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\matplotlib\category.py:106, in StrCategoryConverter.default_units(data, axis)
#     104 # the conversion call stack is default_units -> axis_info -> convert
#     105 if axis.units is None:
# --> 106     axis.set_units(UnitData(data))
#     107 else:
#     108     axis.units.update(data)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\matplotlib\category.py:182, in UnitData.__init__(self, data)
#     180 self._counter = itertools.count()
#     181 if data is not None:
# --> 182     self.update(data)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\matplotlib\category.py:217, in UnitData.update(self, data)
#     214 convertible = True
#     215 for val in OrderedDict.fromkeys(data):
#     216     # OrderedDict just iterates over unique values in data.
# --> 217     _api.check_isinstance((str, bytes), value=val)
#     218     if convertible:
#     219         # this will only be called so long as convertible is True.
#     220         convertible = self._str_is_convertible(val)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\matplotlib\_api\__init__.py:92, in check_isinstance(types, **kwargs)
#      90     names.remove("None")
#      91     names.append("None")
# ---> 92 raise TypeError(
#      93     "{!r} must be an instance of {}, not a {}".format(
#      94         k,
#      95         ", ".join(names[:-1]) + " or " + names[-1]
#      96         if len(names) > 1 else names[0],
#      97         type_name(type(v))))
#
# TypeError: 'value' must be an instance of str or bytes, not a float

# %%
df["Global_active_power"].dtype
# Out:
# dtype('O')

# %%
df["Global_active_power"]=pd.to_numeric(df["Global_active_power"], errors="coerce")
df["Global_active_power"].dtype
# Out:
# dtype('float64')

# %%
import matplotlib.pyplot as plt
df["Global_active_power"].hist()
plt.title="distribution of global active power"
plt.xlabel="KW"
plt.ylabel="frequency"
plt.show()

# %%
import matplotlib.pyplot as plt

df["Global_active_power"].dropna().hist(bins=100)
plt.title="Distribution of Global Active Power"
plt.xlabel="kW"
plt.ylabel="Frequency"
plt.show()

# %% [markdown]
# Handle missing or inconsistent data points

# %%
df.isna().sum()
# Out:
# Global_active_power      25979
# Global_reactive_power        0
# Voltage                      0
# Global_intensity             0
# Sub_metering_1               0
# Sub_metering_2               0
# Sub_metering_3           25979
# Datetime                     0
# hour                         0
# day                          0
# month                        0
# weekday                      0
# dtype: int64

# %%
df
# Out:
#          Global_active_power Global_reactive_power  Voltage Global_intensity  \
# 0                      4.216                 0.418  234.840           18.400
# 1                      5.360                 0.436  233.630           23.000
# 2                      5.374                 0.498  233.290           23.000
# 3                      5.388                 0.502  233.740           23.000
# 4                      3.666                 0.528  235.680           15.800
# ...                      ...                   ...      ...              ...
# 2075254                0.946                   0.0   240.43              4.0
# 2075255                0.944                   0.0    240.0              4.0
# 2075256                0.938                   0.0   239.82              3.8
# 2075257                0.934                   0.0    239.7              3.8
# 2075258                0.932                   0.0   239.55              3.8
#
#         Sub_metering_1 Sub_metering_2  Sub_metering_3            Datetime  \
# 0                0.000          1.000            17.0 2006-12-16 17:24:00
# 1                0.000          1.000            16.0 2006-12-16 17:25:00
# 2                0.000          2.000            17.0 2006-12-16 17:26:00
# 3                0.000          1.000            17.0 2006-12-16 17:27:00
# 4                0.000          1.000            17.0 2006-12-16 17:28:00
# ...                ...            ...             ...                 ...
# 2075254            0.0            0.0             0.0 2010-11-26 20:58:00
# 2075255            0.0            0.0             0.0 2010-11-26 20:59:00
# 2075256            0.0            0.0             0.0 2010-11-26 21:00:00
# 2075257            0.0            0.0             0.0 2010-11-26 21:01:00
# 2075258            0.0            0.0             0.0 2010-11-26 21:02:00
#
#          hour  day  month   weekday
# 0          17   16     12  Saturday
# 1          17   16     12  Saturday
# 2          17   16     12  Saturday
# 3          17   16     12  Saturday
# 4          17   16     12  Saturday
# ...       ...  ...    ...       ...
# 2075254    20   26     11    Friday
# 2075255    20   26     11    Friday
# 2075256    21   26     11    Friday
# 2075257    21   26     11    Friday
# 2075258    21   26     11    Friday
#
# [2075259 rows x 12 columns]

# %%
df.dropna(inplace=True)

# %%
df.isna().sum()
# Out:
# Global_active_power      0
# Global_reactive_power    0
# Voltage                  0
# Global_intensity         0
# Sub_metering_1           0
# Sub_metering_2           0
# Sub_metering_3           0
# Datetime                 0
# hour                     0
# day                      0
# month                    0
# weekday                  0
# dtype: int64

# %% [markdown]
# Create additional features

# %%
df["year"] = df["Datetime"].dt.year
df["minute"] = df["Datetime"].dt.minute
df["is_weekend"] = df["weekday"].isin([5, 6]).astype(int)

# %%
df["date"] = df["Datetime"].dt.date
daily_average = df.groupby("date")["Global_active_power"].mean()
daily_average.head()
# Out:
# date
# 2006-12-16    3.053475
# 2006-12-17    2.354486
# 2006-12-18    1.530435
# 2006-12-19    1.157079
# 2006-12-20    1.545658
# Name: Global_active_power, dtype: float64

# %%
df = df.merge(daily_average.rename("daily_avg_power"),
    on="date",
    how="left"
)

# %%
threshold = df["Global_active_power"].quantile(0.90)
df["peak_hours"]=(df["Global_active_power"]>=threshold).astype(int)

# %%
df = df.sort_values("Datetime")

df["rolling_1h"] = (
    df["Global_active_power"]
    .rolling(window=60, min_periods=1)
    .mean()
)

# %% [markdown]
# Standardization

# %%
num_cols = [
    "Global_active_power",
    "Global_reactive_power",
    "Voltage",
    "Global_intensity",
    "Sub_metering_1",
    "Sub_metering_2",
    "Sub_metering_3",
    "rolling_1h",
]

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

df[num_cols] = scaler.fit_transform(df[num_cols])

# %%
df.head()
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2049280 entries, 0 to 2049279
# Data columns (total 19 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   Global_active_power    float64
#  1   Global_reactive_power  float64
#  2   Voltage                float64
#  3   Global_intensity       float64
#  4   Sub_metering_1         float64
#  5   Sub_metering_2         float64
#  6   Sub_metering_3         float64
#  7   Datetime               datetime64[us]
#  8   hour                   int32
#  9   day                    int32
#  10  month                  int32
#  11  weekday                str
#  12  year                   int32
#  13  minute                 int32
#  14  is_weekend             int64
#  15  date                   object
#  16  daily_avg_power        float64
#  17  peak_hours             int64
#  18  rolling_1h             float64
# dtypes: datetime64[us](1), float64(9), int32(5), int64(2), object(1), str(1)
# memory usage: 258.0+ MB

# %% [markdown]
# Feature Engineering

# %%
TARGET = "Global_active_power"

FEATURES = [
    "Global_intensity",
    "Voltage",
    "Sub_metering_1",
    "Sub_metering_2",
    "Sub_metering_3",
    "daily_avg_power",
    "hour",
    "is_weekend"
]

# %%
df_model = df[FEATURES + [TARGET]].dropna()

# %%
x = df_model[FEATURES]   # DataFrame
y = df_model[TARGET]     # Series

# %%
print(type(x), type(y))
print(x.shape, y.shape)
# Out:
# <class 'pandas.DataFrame'> <class 'pandas.Series'>
# (2049280, 8) (2049280,)

# %%
from sklearn.model_selection import train_test_split

xtrain, xtest, ytrain, ytest = train_test_split(
    x, y, test_size=0.2, random_state=42
)

# %%
from sklearn.model_selection import train_test_split
xtrain, xtest, ytrain, ytest = train_test_split(x,y,test_size=0.2, random_state=42)

# %% [markdown]
# traing the models

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error
import numpy as np

lr = LinearRegression()
lr.fit(xtrain, ytrain)

y_pred_lr = lr.predict(xtest)

mae_lr = mean_absolute_error(ytest, y_pred_lr)
rmse_lr = np.sqrt(mean_squared_error(ytest, y_pred_lr))

print("Linear Regression")
print("MAE :", mae_lr)
print("RMSE:", rmse_lr)
# Out:
# Linear Regression
# MAE : 0.027852355494452596
# RMSE: 0.04183557255738505

# %%
from sklearn.ensemble import RandomForestRegressor

rf = RandomForestRegressor(
    n_estimators=200,
    max_depth=15,
    random_state=42,
    n_jobs=-1
)

rf.fit(xtrain, ytrain)

y_pred_rf = rf.predict(xtest)

mae_rf = mean_absolute_error(ytest, y_pred_rf)
rmse_rf = np.sqrt(mean_squared_error(ytest, y_pred_rf))

print("\nRandom Forest")
print("MAE :", mae_rf)
print("RMSE:", rmse_rf)
# Out:
# Random Forest
# MAE : 0.01803650514363139
# RMSE: 0.0296289333685183

# %%
from sklearn.ensemble import GradientBoostingRegressor

gbr = GradientBoostingRegressor(
    n_estimators=200,
    learning_rate=0.05,
    max_depth=3,
    random_state=42
)

gbr.fit(xtrain, ytrain)

y_pred_gbr = gbr.predict(xtest)

mae_gbr = mean_absolute_error(ytest, y_pred_gbr)
rmse_gbr = np.sqrt(mean_squared_error(ytest, y_pred_gbr))

print("\nGradient Boosting")
print("MAE :", mae_gbr)
print("RMSE:", rmse_gbr)
# Out:
# Gradient Boosting
# MAE : 0.02179417709251199
# RMSE: 0.0340318470272487

# %% [markdown]
# Root Mean Squared Error (RMSE)

# %%
from sklearn.metrics import mean_squared_error
import numpy as np

rmse = np.sqrt(mean_squared_error(ytest, y_pred_lr))
print("RMSE:", rmse)
# Out:
# RMSE: 0.04183557255738505

# %%
from sklearn.metrics import mean_squared_error
import numpy as np

rmse = np.sqrt(mean_squared_error(ytest, y_pred_rf))
print("RMSE:", rmse)
# Out:
# RMSE: 0.0296289333685183

# %%
from sklearn.metrics import mean_squared_error
import numpy as np

rmse = np.sqrt(mean_squared_error(ytest, y_pred_gbr))
print("RMSE:", rmse)
# Out:
# RMSE: 0.0340318470272487
